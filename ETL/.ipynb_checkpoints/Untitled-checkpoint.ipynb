# %%
import pandas as pd

# %%
file_one = "crime.xlsx"

# %%
# file_one_df = pd.read_xlsx(file_one)
file_one_df= pd.read_excel(file_one)

# %%
file_one_df.head(1000)
# Out:
#      ORINumber                Agency  Population  Murder  Rape  Robbery  \
# 0    NJ0010100       ABSECON CITY PD        8252     NaN   NaN      NaN
# 1          NaN    Number of Offenses        8252     1.0   1.0      5.0
# 2          NaN      Rate Per 100,000        8252    12.1  12.1     60.6
# 3          NaN  Number of Clearances        8252     1.0   0.0      0.0
# 4          NaN       Percent Cleared        8252   100.0   0.0      0.0
# ..         ...                   ...         ...     ...   ...      ...
# 995        NaN      Rate Per 100,000       10641     0.0   9.4      9.4
# 996        NaN  Number of Clearances       10641     0.0   0.0      1.0
# 997        NaN       Percent Cleared       10641     0.0   0.0    100.0
# 998        NaN     Number of Arrests       10641     0.0   1.0      5.0
# 999  NJ0043600        WINSLOW TWP PD       38382     NaN   NaN      NaN
#
#      Assault  Burglary  Larceny  Auto Theft    County
# ...

# %%
file_one_df.fillna(0)
# Out:
#       ORINumber                Agency  Population  Murder  Rape  Robbery  \
# 0     NJ0010100       ABSECON CITY PD        8252     0.0   0.0      0.0
# 1             0    Number of Offenses        8252     1.0   1.0      5.0
# 2             0      Rate Per 100,000        8252    12.1  12.1     60.6
# 3             0  Number of Clearances        8252     1.0   0.0      0.0
# 4             0       Percent Cleared        8252   100.0   0.0      0.0
# ...         ...                   ...         ...     ...   ...      ...
# 3370          0    Number of Offenses        6434     0.0   1.0      0.0
# 3371          0      Rate Per 100,000        6434     0.0  15.5      0.0
# 3372          0  Number of Clearances        6434     0.0   0.0      0.0
# 3373          0       Percent Cleared        6434     0.0   0.0      0.0
# 3374          0     Number of Arrests        6434     0.0   0.0      0.0
#
#       Assault  Burglary  Larceny  Auto Theft    County
# ...

# %%
file_one_df.count()
# Out:
# ORINumber      578
# Agency        3375
# Population    3375
# Murder        2797
# Rape          2797
# Robbery       2797
# Assault       2797
# Burglary      2797
# Larceny       2797
# Auto Theft    2797
# County        3375
# dtype: int64

# %%
#orin_pd_pop = file_one_df[["ORINumber", "Agency", "Agency"]].copy()
# orin_pd_pop.head()
# orin_pd_pop.count()
# Clean=orin_pd_pop.dropna() 
# Clean.count()

# %%
#for row in file_one_df.itertuples():
   # print(row.ORINumber,)

# %% [markdown]
# ###### Pseudo Code
# User the function iterow and iteritate through each row.
# If ORINumber column is has a value which starts with NJ% convert that to a rown item
# In the same row if murder = 0 then pick up Agency name , population and County value
# If ORINumber = "NJ%" and Agency = "Number of Offenses"
#    DF [] = Murder, Rape, Autothef
#
# Web Reference = https://cmdlinetips.com/2018/12/how-to-loop-through-pandas-rows-or-how-to-iterate-over-pandas-rows/

# %%
for index, row in file_one_df.iterrows():
     print(index, row.ORINumber,row.Agency,row.Population,row.County,row.Murder,row.Rape)
# Out:
# 0 NJ0010100 ABSECON CITY PD 8252 Atlantic nan nan
# 1 nan Number of Offenses 8252 Atlantic 1.0 1.0
# 2 nan Rate Per 100,000 8252 Atlantic 12.1 12.1
# 3 nan Number of Clearances 8252 Atlantic 1.0 0.0
# 4 nan Percent Cleared 8252 Atlantic 100.0 0.0
# 5 nan Number of Arrests 8252 Atlantic 1.0 0.0
# 6 NJ0010200 ATLANTIC CITY PD 38271 Atlantic nan nan
# 7 nan Number of Offenses 38271 Atlantic 7.0 11.0
# 8 nan Rate Per 100,000 38271 Atlantic 18.3 28.7
# 9 nan Number of Clearances 38271 Atlantic 6.0 3.0
# 10 nan Percent Cleared 38271 Atlantic 86.0 27.0
# 11 nan Number of Arrests 38271 Atlantic 4.0 5.0
# 12 NJ0010000 ATLANTIC CO SHERIFF'S  OFFICE 0 Atlantic nan nan
# 13 nan Number of Offenses 0 Atlantic 0.0 0.0
# 14 nan Rate Per 100,000 0 Atlantic 0.0 0.0
# 15 nan Number of Clearances 0 Atlantic 0.0 0.0
# 16 nan Percent Cleared 0 Atlantic 0.0 0.0
# 17 nan Number of Arrests 0 Atlantic 0.0 0.0
# 18 NJ0018900 ATLANTIC COUNTY PROSECUTOR'S OFFICE 0 Atlantic nan nan
# ...

# %%
for index, row in df.iterrows():
     if row ["ORINumber"]=[NJ%]
        df [""] = df(row.ORINnumber, row.county,row.population) 
        if ["ORINumber"] = "NJ%" and ["Agency"] = "Number of Offenses"
           df = (row.Murder,row.Rape,row.Robbery,row.Assault,row.Burglary,row.Larceny.row.Auto Theft)
# Out:
#   File "<ipython-input-11-714dd72be60e>", line 2
#     if row ["ORINumber"]=[NJ%]
#                         ^
# SyntaxError: invalid syntax
