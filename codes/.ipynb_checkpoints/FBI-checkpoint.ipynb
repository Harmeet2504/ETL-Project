# %%
import requests
import json
import pandas as pd
import numpy as np
from config import api_key,fbi_key,pword
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-94-a64994501093> in <module>
#       3 import pandas as pd
#       4 import numpy as np
# ----> 5 from config import api_key,fbi_key,pword
#       6 from sqlalchemy import create_engine
#       7 import warnings
#
# ImportError: cannot import name 'pword' from 'config' (C:\Users\woodf\EconFin\ETL-FBI_Census\codes\config.py)

# %%
#write api call for 2017 data and get response
long_url2 = "https://api.census.gov/data/2017/acs/acs5/profile?get=DP05_0001E,DP02_0037PE,DP02_0061PE,DP03_0009PE,DP03_0128PE,DP03_0063E,DP05_0004E,DP05_0018E,NAME&for=county:*&in=state:34&key="
response2 = requests.get(long_url2 + api_key)
print(response2)
# Out:
# <Response [200]>

# %%
#read json
response2=response2.json()

# %%
#convert to dataframe and clean up header
census_pd = pd.DataFrame(response2)
census_pd.columns = census_pd.iloc[0]
census_pd = census_pd.iloc[1:]
census_pd.head()
# Out:
# 0 DP05_0001E DP02_0037PE DP02_0061PE DP03_0009PE DP03_0128PE DP03_0063E  \
# 1     589699        22.2        34.3         6.7        10.9      86433
# 2     272926        44.1        33.0        10.9        15.3      78395
# 3     291372        29.2        33.8         7.4         7.9      98029
# 4     837288        23.8        25.8         6.4         8.6     104526
# 5      63776        48.7        38.0         8.0        14.2      81352
#
# 0 DP05_0004E DP05_0018E                           NAME state county
# 1       92.9       42.9       Ocean County, New Jersey    34    029
# 2       93.9       41.1    Atlantic County, New Jersey    34    001
# 3       94.5       39.9  Gloucester County, New Jersey    34    015
# 4       96.9       38.1   Middlesex County, New Jersey    34    023
# 5       95.2       41.9       Salem County, New Jersey    34    033

# %%
#rename columns
census_pd = census_pd.rename(columns={"DP05_0001E": "population","DP02_0037PE": "pct_births_single_moms",
                                                  "DP02_0061PE": "pct_hs_diploma","DP03_0009PE":"unemployment",
                                                  "DP03_0128PE":"pct_under_pvt_lvl","DP03_0063E":"mean_income",
                                                  "DP05_0004E":"sex_ratio","DP05_0018E":"mean_age", "NAME":"county_name"})
census_pd.head()
# Out:
# 0 population pct_births_single_moms pct_hs_diploma unemployment  \
# 1     589699                   22.2           34.3          6.7
# 2     272926                   44.1           33.0         10.9
# 3     291372                   29.2           33.8          7.4
# 4     837288                   23.8           25.8          6.4
# 5      63776                   48.7           38.0          8.0
#
# 0 pct_under_pvt_lvl mean_income sex_ratio mean_age  \
# 1              10.9       86433      92.9     42.9
# 2              15.3       78395      93.9     41.1
# 3               7.9       98029      94.5     39.9
# 4               8.6      104526      96.9     38.1
# 5              14.2       81352      95.2     41.9
#
# 0                    county_name state county
# 1       Ocean County, New Jersey    34    029
# 2    Atlantic County, New Jersey    34    001
# 3  Gloucester County, New Jersey    34    015
# 4   Middlesex County, New Jersey    34    023
# 5       Salem County, New Jersey    34    033

# %%
census_pd.keys()
# Out:
# Index(['population', 'pct_births_single_moms', 'pct_hs_diploma',
#        'unemployment', 'pct_under_pvt_lvl', 'mean_income', 'sex_ratio',
#        'mean_age', 'county_name', 'state', 'county'],
#       dtype='object', name=0)

# %%
#re-order columns
census_pd= census_pd[['county','state','county_name','population', 'pct_births_single_moms', 'pct_hs_diploma',
       'unemployment', 'pct_under_pvt_lvl', 'mean_income', 'sex_ratio',
       'mean_age']]

# %%
census_pd.head()
# Out:
# 0 county state                    county_name population  \
# 1    029    34       Ocean County, New Jersey     589699
# 2    001    34    Atlantic County, New Jersey     272926
# 3    015    34  Gloucester County, New Jersey     291372
# 4    023    34   Middlesex County, New Jersey     837288
# 5    033    34       Salem County, New Jersey      63776
#
# 0 pct_births_single_moms pct_hs_diploma unemployment pct_under_pvt_lvl  \
# 1                   22.2           34.3          6.7              10.9
# 2                   44.1           33.0         10.9              15.3
# 3                   29.2           33.8          7.4               7.9
# 4                   23.8           25.8          6.4               8.6
# 5                   48.7           38.0          8.0              14.2
#
# 0 mean_income sex_ratio mean_age
# 1       86433      92.9     42.9
# 2       78395      93.9     41.1
# 3       98029      94.5     39.9
# 4      104526      96.9     38.1
# 5       81352      95.2     41.9

# %%
#clean up county name strings
census_pd['county_name'] = census_pd['county_name'].str.rstrip('New Jersey')
census_pd['county_name'] = census_pd['county_name'].str.rstrip('County,')

census_pd.head()
# Out:
# 0 county state  county_name population pct_births_single_moms pct_hs_diploma  \
# 1    029    34       Ocean      589699                   22.2           34.3
# 2    001    34    Atlantic      272926                   44.1           33.0
# 3    015    34  Gloucester      291372                   29.2           33.8
# 4    023    34   Middlesex      837288                   23.8           25.8
# 5    033    34       Salem       63776                   48.7           38.0
#
# 0 unemployment pct_under_pvt_lvl mean_income sex_ratio mean_age
# 1          6.7              10.9       86433      92.9     42.9
# 2         10.9              15.3       78395      93.9     41.1
# 3          7.4               7.9       98029      94.5     39.9
# 4          6.4               8.6      104526      96.9     38.1
# 5          8.0              14.2       81352      95.2     41.9

# %%
#write df to csv
census_pd.to_csv("../output_files/census.csv")

# %%
#write api call NJ police departments from FBI API and get response
long_url2 = "https://api.usa.gov/crime/fbi/sapi/api/agencies/byStateAbbr/raw/NJ?API_KEY="
response2 = requests.get(long_url2+fbi_key)
print(response2)
# Out:
# <Response [200]>

# %%
#read json
response2=response2.json()

# %%
#define function to "de-nest" the multi-layered dictionary

def de_nest(nest):
    dict1 = {}
    
    for key in nest.values():
        dict1.update(key)
    
    list1 = []
    for key in dict1.values():
        list1.append(key)
    
    df1 = pd.DataFrame(list1)
    
    return df1

# %%
#create nj police dept dataframe
nj_df = de_nest(response2)

# %%
#check dataframe
nj_df.head()
# Out:
#                              agency_name agency_type_name county_name  \
# 0              Bayonne Police Department             City      HUDSON
# 1               Orange Police Department             City       ESSEX
# 2  Long Beach Township Police Department             City       OCEAN
# 3         Midland Park Police Department             City      BERGEN
# 4         Saddle River Police Department             City      BERGEN
#
#      division_name   latitude  longitude  nibrs nibrs_start_date        ori  \
# 0  Middle Atlantic  40.731384 -74.078627  False             None  NJ0090100
# 1  Middle Atlantic  40.771152 -74.224846  False             None  NJ0071700
# 2  Middle Atlantic  39.616623 -74.200310  False             None  NJ0151700
# 3  Middle Atlantic  40.991100 -74.141540  False             None  NJ0023500
# 4  Middle Atlantic  41.031727 -74.098526  False             None  NJ0025800
#
#   region_desc region_name state_abbr  state_name
# 0    Region I   Northeast         NJ  New Jersey
# 1    Region I   Northeast         NJ  New Jersey
# 2    Region I   Northeast         NJ  New Jersey
# 3    Region I   Northeast         NJ  New Jersey
# 4    Region I   Northeast         NJ  New Jersey

# %%
#get keys
nj_df.keys()
# Out:
# Index(['agency_name', 'agency_type_name', 'county_name', 'division_name',
#        'latitude', 'longitude', 'nibrs', 'nibrs_start_date', 'ori',
#        'region_desc', 'region_name', 'state_abbr', 'state_name'],
#       dtype='object')

# %%
#drop unwanted columns
nj_df.drop(['agency_type_name', 'division_name','latitude', 'longitude','nibrs','nibrs_start_date','region_desc',
            'region_name', 'state_abbr', 'state_name'], inplace=True, axis=1)
nj_df.head()
# Out:
#                              agency_name county_name        ori
# 0              Bayonne Police Department      HUDSON  NJ0090100
# 1               Orange Police Department       ESSEX  NJ0071700
# 2  Long Beach Township Police Department       OCEAN  NJ0151700
# 3         Midland Park Police Department      BERGEN  NJ0023500
# 4         Saddle River Police Department      BERGEN  NJ0025800

# %%
#export to csv
nj_df.to_csv("../output_files/agencies.csv")

# %%
#create list of offenses in the FBI API
offenses_list = ["aggravated-assault","burglary","larceny","motor-vehicle-theft",
                 "homicide","rape","robbery","arson","violent-crime","property-crime"]

# %%
#run for loop to run through each offence and every API page per offence 
offense_jsons = []
url1 = "https://api.usa.gov/crime/fbi/sapi/api/summarized/state/NJ/"
url2 = "/2017/2017?API_KEY="
for crime in offenses_list:
    url = url1 + crime + url2 + fbi_key
    response = requests.get(url).json()
    num_pages = response["pagination"]["pages"]
    for page in range(num_pages + 1):
        response2 = requests.get(url1+crime+url2+fbi_key, params={'page': page})
        print(response2)
        response2 = response2.json()
        offense_jsons.append(response2)
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
#delete pagination key
for x in range(len(offense_jsons)):
    del offense_jsons[x]['pagination']

# %%
#create inpack function to unpack nested dictionaries and convert to dataframe
def unpack(jumble):
    [list1] = [key for key in jumble.values()]
    df1 = pd.DataFrame(list1)
    return df1

# %%
# Use pd.concat to merge a list of DataFrame into a single big DataFrame.
new_df = []
for x in range(len(offense_jsons)):
    data = unpack(offense_jsons[x])
    new_df.append(data)
    
new_df = pd.concat(new_df)
# Use pd.concat to merge a list of DataFrame into a single big DataFrame.

# %%
#reset index and check tail
new_df.reset_index(drop=True).tail()
# Out:
#       actual  cleared  data_year         offense        ori state_abbr
# 5935      92       17       2017  property-crime  NJ0025400         NJ
# 5936       1        0       2017  property-crime  NJ0025500         NJ
# 5937     206       27       2017  property-crime  NJ0025600         NJ
# 5938     247       80       2017  property-crime  NJ0025700         NJ
# 5939      19        7       2017  property-crime  NJ0025800         NJ

# %%
#merge crime and agency dataframes
crime_df = pd.merge(new_df, nj_df, on="ori",how="left")

# %%
#check table length
print(f'Our crime table has {crime_df.shape[0]} rows')
crime_df.head()
# Out:
# Our crime table has 5940 rows
#    actual  cleared  data_year             offense        ori state_abbr  \
# 0      13        5       2017  aggravated-assault  NJ0012100         NJ
# 1       2        2       2017  aggravated-assault  NJ0012200         NJ
# 2       0        0       2017  aggravated-assault  NJ0012400         NJ
# 3      28       11       2017  aggravated-assault  NJ001SP00         NJ
# 4       3        2       2017  aggravated-assault  NJ0020000         NJ
#
#                       agency_name county_name
# 0  Somers Point Police Department    ATLANTIC
# 1  Ventnor City Police Department    ATLANTIC
# 2             Stockton University    ATLANTIC
# 3   State Police: Atlantic County    ATLANTIC
# 4  Bergen County Sheriff's Office      BERGEN

# %%
crime_df.to_csv("../output_files/FBI.csv")

# %%
#create pivot table summing total offenses by type by county
crime_pivot = pd.pivot_table(crime_df, index= 'county_name', columns= 'offense', values= "actual", fill_value=0, aggfunc='sum')
crime_pivot
# Out:
# offense      aggravated-assault  arson  burglary  homicide  larceny  \
# county_name
# ATLANTIC                   1189     39       841        42     3775
# BERGEN                      234     37       796         5     8182
# BURLINGTON                  140     16      2052         9     6768
# CAMDEN                     2511     27      3094        29    11968
# CAPE MAY                    241      5       903         2      625
# CUMBERLAND                  421     48      1354        16     4213
# ESSEX                      1888    123       213       177     7443
# GLOUCESTER                  209     20       680         4     2128
# HUDSON                      962     88      1660         1     2975
# HUNTERDON                    15      2        60         0      733
# MERCER                        0     27       960         0     2896
# MIDDLESEX                   481     13      1742        23     5567
# MONMOUTH                    483     15       852        15     3553
# MORRIS                       52      4       192         6     2844
# N/A                          72      1         0         0      759
# OCEAN                       204     25      1888         2    10219
# PASSAIC                     845     16      3340        26    11661
# SALEM                       110      0       295         3     2318
# SOMERSET                    126     10       986         0     8177
# SUSSEX                       58      5       436         0       22
# UNION                      1144     18      4910        13     3779
# WARREN                       55      4        46         2      795
#
# offense      motor-vehicle-theft  property-crime  rape  rape-legacy  robbery  \
# county_name
# ATLANTIC                     228               0    59            0      181
# BERGEN                       780           14921    82            0      460
# BURLINGTON                   423           12651   167            0       93
# CAMDEN                       286           19908    57            0      666
# CAPE MAY                      17               0    28            0       21
# CUMBERLAND                   150               0     0            0      300
# ESSEX                       2937           12277   206            0      310
# GLOUCESTER                   236             127    32            0      281
# HUDSON                       127               0    33            0     1510
# HUNTERDON                     21             482     3            0        8
# MERCER                       240           13763    71            0      395
# MIDDLESEX                    604           14016     8            0      399
# MONMOUTH                     311           12295   106            0      129
# MORRIS                       316            4231    51            0       32
# N/A                           21             298     0            0       18
# OCEAN                        324               0    60            0      105
# PASSAIC                     2962           15670    21            0      754
# SALEM                          0            1157    23            0        0
# SOMERSET                      85            1923    24            0       88
# SUSSEX                        54             728    10            0        0
# UNION                       1176            9751    49            0       96
# WARREN                        11            1325    14            0       28
#
# offense      violent-crime
# county_name
# ATLANTIC              1882
# BERGEN                 318
# BURLINGTON             548
# CAMDEN                4025
# CAPE MAY               270
# CUMBERLAND             802
# ESSEX                 6940
# GLOUCESTER             169
# HUDSON                2190
# HUNTERDON                2
# MERCER                1283
# MIDDLESEX              472
# MONMOUTH              1987
# MORRIS                 270
# N/A                    130
# OCEAN                   26
# PASSAIC               4863
# SALEM                   20
# SOMERSET                 0
# SUSSEX                  28
# UNION                 2453
# WARREN                 110

# %%
#flatten the table
crime_pivot.columns = crime_pivot.columns.get_level_values('offense')
crime_pivot.reset_index(inplace=True)

# %%
#check crime pivot
crime_pivot
# Out:
# offense county_name  aggravated-assault  arson  burglary  homicide  larceny  \
# 0          ATLANTIC                1189     39       841        42     3775
# 1            BERGEN                 234     37       796         5     8182
# 2        BURLINGTON                 140     16      2052         9     6768
# 3            CAMDEN                2511     27      3094        29    11968
# 4          CAPE MAY                 241      5       903         2      625
# 5        CUMBERLAND                 421     48      1354        16     4213
# 6             ESSEX                1888    123       213       177     7443
# 7        GLOUCESTER                 209     20       680         4     2128
# 8            HUDSON                 962     88      1660         1     2975
# 9         HUNTERDON                  15      2        60         0      733
# 10           MERCER                   0     27       960         0     2896
# 11        MIDDLESEX                 481     13      1742        23     5567
# 12         MONMOUTH                 483     15       852        15     3553
# 13           MORRIS                  52      4       192         6     2844
# 14              N/A                  72      1         0         0      759
# 15            OCEAN                 204     25      1888         2    10219
# 16          PASSAIC                 845     16      3340        26    11661
# 17            SALEM                 110      0       295         3     2318
# 18         SOMERSET                 126     10       986         0     8177
# 19           SUSSEX                  58      5       436         0       22
# 20            UNION                1144     18      4910        13     3779
# 21           WARREN                  55      4        46         2      795
#
# offense  motor-vehicle-theft  property-crime  rape  rape-legacy  robbery  \
# 0                        228               0    59            0      181
# 1                        780           14921    82            0      460
# 2                        423           12651   167            0       93
# 3                        286           19908    57            0      666
# 4                         17               0    28            0       21
# 5                        150               0     0            0      300
# 6                       2937           12277   206            0      310
# 7                        236             127    32            0      281
# 8                        127               0    33            0     1510
# 9                         21             482     3            0        8
# 10                       240           13763    71            0      395
# 11                       604           14016     8            0      399
# 12                       311           12295   106            0      129
# 13                       316            4231    51            0       32
# 14                        21             298     0            0       18
# 15                       324               0    60            0      105
# 16                      2962           15670    21            0      754
# 17                         0            1157    23            0        0
# 18                        85            1923    24            0       88
# 19                        54             728    10            0        0
# 20                      1176            9751    49            0       96
# 21                        11            1325    14            0       28
#
# offense  violent-crime
# 0                 1882
# 1                  318
# 2                  548
# 3                 4025
# 4                  270
# 5                  802
# 6                 6940
# 7                  169
# 8                 2190
# 9                    2
# 10                1283
# 11                 472
# 12                1987
# 13                 270
# 14                 130
# 15                  26
# 16                4863
# 17                  20
# 18                   0
# 19                  28
# 20                2453
# 21                 110

# %%
#assign county id's to crime pivot table
id_df = census_pd[['county','state','county_name']]
id_df['county_name'] = id_df['county_name'].str.upper() 
id_df.sort_values('county_name', inplace=True)
id_df.reset_index(drop=True, inplace=True)
id_df.head()
# Out:
# 0 county state  county_name
# 0    001    34    ATLANTIC
# 1    003    34      BERGEN
# 2    005    34  BURLINGTON
# 3    007    34      CAMDEN
# 4    009    34    CAPE MAY

# %%
#strip out any white space before merging on county_name
id_df["county_name"] = id_df["county_name"].str.strip()
crime_pivot["county_name"] = crime_pivot["county_name"].str.strip()

# %%
#merge county id's with crime data
county_crime = pd.merge(crime_pivot, id_df, on="county_name")
county_crime
# Out:
#    county_name  aggravated-assault  arson  burglary  homicide  larceny  \
# 0     ATLANTIC                1189     39       841        42     3775
# 1       BERGEN                 234     37       796         5     8182
# 2   BURLINGTON                 140     16      2052         9     6768
# 3       CAMDEN                2511     27      3094        29    11968
# 4     CAPE MAY                 241      5       903         2      625
# 5   CUMBERLAND                 421     48      1354        16     4213
# 6        ESSEX                1888    123       213       177     7443
# 7   GLOUCESTER                 209     20       680         4     2128
# 8       HUDSON                 962     88      1660         1     2975
# 9    HUNTERDON                  15      2        60         0      733
# 10      MERCER                   0     27       960         0     2896
# 11   MIDDLESEX                 481     13      1742        23     5567
# 12    MONMOUTH                 483     15       852        15     3553
# 13      MORRIS                  52      4       192         6     2844
# 14       OCEAN                 204     25      1888         2    10219
# 15     PASSAIC                 845     16      3340        26    11661
# 16       SALEM                 110      0       295         3     2318
# 17    SOMERSET                 126     10       986         0     8177
# 18      SUSSEX                  58      5       436         0       22
# 19       UNION                1144     18      4910        13     3779
# 20      WARREN                  55      4        46         2      795
#
#     motor-vehicle-theft  property-crime  rape  rape-legacy  robbery  \
# 0                   228               0    59            0      181
# 1                   780           14921    82            0      460
# 2                   423           12651   167            0       93
# 3                   286           19908    57            0      666
# 4                    17               0    28            0       21
# 5                   150               0     0            0      300
# 6                  2937           12277   206            0      310
# 7                   236             127    32            0      281
# 8                   127               0    33            0     1510
# 9                    21             482     3            0        8
# 10                  240           13763    71            0      395
# 11                  604           14016     8            0      399
# 12                  311           12295   106            0      129
# 13                  316            4231    51            0       32
# 14                  324               0    60            0      105
# 15                 2962           15670    21            0      754
# 16                    0            1157    23            0        0
# 17                   85            1923    24            0       88
# 18                   54             728    10            0        0
# 19                 1176            9751    49            0       96
# 20                   11            1325    14            0       28
#
#     violent-crime county state
# 0            1882    001    34
# 1             318    003    34
# 2             548    005    34
# 3            4025    007    34
# 4             270    009    34
# 5             802    011    34
# 6            6940    013    34
# 7             169    015    34
# 8            2190    017    34
# 9               2    019    34
# 10           1283    021    34
# 11            472    023    34
# 12           1987    025    34
# 13            270    027    34
# 14             26    029    34
# 15           4863    031    34
# 16             20    033    34
# 17              0    035    34
# 18             28    037    34
# 19           2453    039    34
# 20            110    041    34

# %%
#reorder columns and delete columns with no data
county_crime = county_crime[[ 'state', 'county','county_name','aggravated-assault',
 'arson','burglary','homicide','larceny','motor-vehicle-theft','property-crime','rape','robbery','violent-crime'
]]

# %%
#create column that sums all offenses for each county
county_crime['total_offenses']= county_crime.iloc[:, 3:12].sum(axis=1)

# %%
county_crime.head()
# Out:
#   state county county_name  aggravated-assault  arson  burglary  homicide  \
# 0    34    001    ATLANTIC                1189     39       841        42
# 1    34    003      BERGEN                 234     37       796         5
# 2    34    005  BURLINGTON                 140     16      2052         9
# 3    34    007      CAMDEN                2511     27      3094        29
# 4    34    009    CAPE MAY                 241      5       903         2
#
#    larceny  motor-vehicle-theft  property-crime  rape  robbery  violent-crime  \
# 0     3775                  228               0    59      181           1882
# 1     8182                  780           14921    82      460            318
# 2     6768                  423           12651   167       93            548
# 3    11968                  286           19908    57      666           4025
# 4      625                   17               0    28       21            270
#
#    Total Offenses  total_offenses
# 0            6354            6354
# 1           25497           25497
# 2           22319           22319
# 3           38546           38546
# 4            1842            1842

# %%
county_crime.to_csv("../output_files/county_crime.csv")

# %%
#connect to local database
rds_connection_string = "postgres:"+ pword + "@localhost:5432/nj_crime"
engine = create_engine(f'postgresql://{rds_connection_string}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-92-d5694e8ca217> in <module>
#       1 #connect to local database
# ----> 2 rds_connection_string = "postgres:"+ pword + "@localhost:5432/nj_crime"
#       3 engine = create_engine(f'postgresql://{rds_connection_string}')
#
# NameError: name 'pword' is not defined

# %%
#export census data to SQL
census_pd.to_sql(name='census', con=engine, if_exists='replace', index=True)

# %%
#export crime data to SQL 
county_crime.to_sql(name='crime', con=engine, if_exists='replace', index=True)

# %%
engine.table_names()
# Out:
# ['census', 'crime']

# %%
#read tables from SQL
pd.read_sql("SELECT * FROM census",con=engine)
# Out:
#     index county state  county_name population pct_births_single_moms  \
# 0       1    029    34       Ocean      589699                   22.2
# 1       2    001    34    Atlantic      272926                   44.1
# 2       3    015    34  Gloucester      291372                   29.2
# 3       4    023    34   Middlesex      837288                   23.8
# 4       5    033    34       Salem       63776                   48.7
# 5       6    031    34     Passaic      510563                   33.5
# 6       7    009    34    Cape May       94549                   12.4
# 7       8    007    34      Camden      510996                   44.8
# 8       9    003    34      Bergen      937920                   18.6
# 9      10    039    34       Union      557320                   33.7
# 10     11    041    34      Warren      107088                   34.6
# 11     12    017    34      Hudson      679756                   25.7
# 12     13    019    34   Hunterdon      125717                   21.6
# 13     14    005    34  Burlington      449192                   31.3
# 14     15    027    34      Morris      498847                   12.2
# 15     16    025    34    Monmouth      627551                   30.1
# 16     17    021    34      Mercer      373362                   36.3
# 17     18    037    34      Sussex      143570                   20.9
# 18     19    013    34       Essex      800401                   40.7
# 19     20    011    34  Cumberland      154952                   50.6
# 20     21    035    34    Somerset      333316                   15.4
#
#    pct_hs_diploma unemployment pct_under_pvt_lvl mean_income sex_ratio  \
# 0            34.3          6.7              10.9       86433      92.9
# 1            33.0         10.9              15.3       78395      93.9
# 2            33.8          7.4               7.9       98029      94.5
# 3            25.8          6.4               8.6      104526      96.9
# 4            38.0          8.0              14.2       81352      95.2
# 5            34.6          6.0              17.0       86232      94.7
# 6            33.0          8.4              10.6       85182      95.4
# 7            30.7          7.9              13.1       86179      93.5
# 8            23.9          5.2               7.2      126475      93.9
# 9            29.2          7.4              10.3      108110      95.1
# 10           31.5          7.4               8.2       94806      95.2
# 11           26.2          7.1              17.1       92630      98.5
# 12           21.7          4.4               4.5      143633     100.1
# 13           28.9          6.9               6.4      104955      96.8
# 14           21.1          5.2               4.6      145273      96.1
# 15           24.7          6.0               7.6      123664      94.7
# 16           24.6          7.5              11.3      111137      95.8
# 17           31.4          6.4               5.3      108722      99.1
# 18           28.4         10.4              16.7       95235      92.5
# 19           39.2          9.0              18.8       65539     105.5
# 20           21.1          4.9               4.8      144629      95.4
#
#    mean_age
# 0      42.9
# 1      41.1
# 2      39.9
# 3      38.1
# 4      41.9
# 5      36.7
# 6      48.7
# 7      38.5
# 8      41.6
# 9      38.3
# 10     43.5
# 11     34.9
# 12     45.9
# 13     41.4
# 14     42.3
# 15     42.8
# 16     38.6
# 17     44.1
# 18     37.3
# 19     36.8
# 20     41.3

# %%
pd.read_sql("SELECT * FROM crime",con=engine)
# Out:
#     index state county county_name  aggravated-assault  arson  burglary  \
# 0       0    34    001    ATLANTIC                1189     39       841
# 1       1    34    003      BERGEN                 234     37       796
# 2       2    34    005  BURLINGTON                 140     16      2052
# 3       3    34    007      CAMDEN                2511     27      3094
# 4       4    34    009    CAPE MAY                 241      5       903
# 5       5    34    011  CUMBERLAND                 421     48      1354
# 6       6    34    013       ESSEX                1888    123       213
# 7       7    34    015  GLOUCESTER                 209     20       680
# 8       8    34    017      HUDSON                 962     88      1660
# 9       9    34    019   HUNTERDON                  15      2        60
# 10     10    34    021      MERCER                   0     27       960
# 11     11    34    023   MIDDLESEX                 481     13      1742
# 12     12    34    025    MONMOUTH                 483     15       852
# 13     13    34    027      MORRIS                  52      4       192
# 14     14    34    029       OCEAN                 204     25      1888
# 15     15    34    031     PASSAIC                 845     16      3340
# 16     16    34    033       SALEM                 110      0       295
# 17     17    34    035    SOMERSET                 126     10       986
# 18     18    34    037      SUSSEX                  58      5       436
# 19     19    34    039       UNION                1144     18      4910
# 20     20    34    041      WARREN                  55      4        46
#
#     homicide  larceny  motor-vehicle-theft  property-crime  rape  robbery  \
# 0         42     3775                  228               0    59      181
# 1          5     8182                  780           14921    82      460
# 2          9     6768                  423           12651   167       93
# 3         29    11968                  286           19908    57      666
# 4          2      625                   17               0    28       21
# 5         16     4213                  150               0     0      300
# 6        177     7443                 2937           12277   206      310
# 7          4     2128                  236             127    32      281
# 8          1     2975                  127               0    33     1510
# 9          0      733                   21             482     3        8
# 10         0     2896                  240           13763    71      395
# 11        23     5567                  604           14016     8      399
# 12        15     3553                  311           12295   106      129
# 13         6     2844                  316            4231    51       32
# 14         2    10219                  324               0    60      105
# 15        26    11661                 2962           15670    21      754
# 16         3     2318                    0            1157    23        0
# 17         0     8177                   85            1923    24       88
# 18         0       22                   54             728    10        0
# 19        13     3779                 1176            9751    49       96
# 20         2      795                   11            1325    14       28
#
#     violent-crime  total_offenses
# 0            1882            6354
# 1             318           25497
# 2             548           22319
# 3            4025           38546
# 4             270            1842
# 5             802            6502
# 6            6940           25574
# 7             169            3717
# 8            2190            7356
# 9               2            1324
# 10           1283           18352
# 11            472           22853
# 12           1987           17759
# 13            270            7728
# 14             26           12827
# 15           4863           35295
# 16             20            3906
# 17              0           11419
# 18             28            1313
# 19           2453           20936
# 20            110            2280

# %%
#run a test JOIN 
pd.read_sql_query('SELECT \
cr.county_name, cr.total_offenses, ce.Pct_Under_Pvt_Lvl \
FROM crime AS cr \
JOIN census AS ce \
ON cr.county = ce.county;', con=engine)
# Out:
#    county_name  total_offenses pct_under_pvt_lvl
# 0     ATLANTIC            6354              15.3
# 1       BERGEN           25497               7.2
# 2   BURLINGTON           22319               6.4
# 3       CAMDEN           38546              13.1
# 4     CAPE MAY            1842              10.6
# 5   CUMBERLAND            6502              18.8
# 6        ESSEX           25574              16.7
# 7   GLOUCESTER            3717               7.9
# 8       HUDSON            7356              17.1
# 9    HUNTERDON            1324               4.5
# 10      MERCER           18352              11.3
# 11   MIDDLESEX           22853               8.6
# 12    MONMOUTH           17759               7.6
# 13      MORRIS            7728               4.6
# 14       OCEAN           12827              10.9
# 15     PASSAIC           35295              17.0
# 16       SALEM            3906              14.2
# 17    SOMERSET           11419               4.8
# 18      SUSSEX            1313               5.3
# 19       UNION           20936              10.3
# 20      WARREN            2280               8.2
